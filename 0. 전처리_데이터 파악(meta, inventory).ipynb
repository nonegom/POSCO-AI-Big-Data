# %%
import pandas as pd
import numpy as np

# 데이터 시각화 패키지
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.api import add_constant

from sklearn.svm import SVC 

# 모델 전처리
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV


# grhpviz
from sklearn.tree import export_graphviz
import graphviz

# 로지스틱 회귀
from statsmodels.api import Logit
from sklearn.metrics import accuracy_score

# 의사결정나무
from sklearn.tree import DecisionTreeClassifier


# 랜덤포레스트
from sklearn.ensemble import RandomForestClassifier

# 그레디언트 부스팅
from sklearn.ensemble import GradientBoostingClassifier

# 모델 성능 평가
from sklearn.metrics import confusion_matrix

# 주피터 노트북 사용시 그래프 자동 출력 옵션
# %matplotlib inline
matplotlib.rc('font', family = "NanumGothic")
plt.rc('font', family = "NanumGothic")
plt.rcParams["font.family"] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df_raw_meta = pd.read_csv("Data_OTT//movie_meta.csv", encoding="cp949")

# %%
df_raw = pd.read_csv("Data_OTT/movie_inventory.csv", encoding="cp949")

# %%
df_raw.head()
# Out:
#   item_id  contract_year   movie_id  \
# 0  I-1001           2015  tt0121766
# 1  I-1002           2015  tt0330373
# 2  I-1003           2015  tt0363771
# 3  I-1004           2015  tt0383574
# 4  I-1005           2015  tt0413300
#
#                                           title  release_year release_date  \
# 0  Star Wars: Episode III - Revenge of the Sith          2005   05-19-2005
# 1           Harry Potter and the Goblet of Fire          2005   11-18-2005
# 2  The Chronicles of Narnia: The Lion, the Witc          2005   12-09-2005
# 3    Pirates of the Caribbean: Dead Man's Chest          2006   07-07-2006
# 4                                  Spider-Man 3          2007   05-04-2007
#
#    runtime mpa_rating mpa_rating_origin  imdb_score  ...        director  \
# 0      140      PG-13             PG-13         7.5  ...    George Lucas
# 1      157      PG-13             PG-13         7.7  ...     Mike Newell
# 2      143         PG                PG         6.9  ...  Andrew Adamson
# 3      151      PG-13             PG-13         7.3  ...  Gore Verbinski
# 4      139      PG-13             PG-13         6.2  ...       Sam Raimi
#
#      Genre_1    Genre_2  Genre_3         actor_1          actor_2  \
# 0     Action  Adventure  Fantasy   Ewan McGregor  Natalie Portman
# 1  Adventure     Family  Fantasy      Eric Sykes    Timothy Spall
# 2  Adventure     Family  Fantasy  Georgie Henley   Skandar Keynes
# 3     Action  Adventure  Fantasy     Johnny Depp    Orlando Bloom
# 4     Action  Adventure   Sci-Fi   Tobey Maguire    Kirsten Dunst
#
#               actor_3  contract_price studio_score price_class
# 0  Hayden Christensen            2700           10          10
# 1       David Tennant            2700           10          10
# 2     William Moseley            2295           10           1
# 3     Keira Knightley            2295           10           1
# 4        James Franco            2295           10           1
#
# [5 rows x 32 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   item_id            106 non-null    object
#  1   contract_year      106 non-null    int64
#  2   movie_id           106 non-null    object
#  3   title              106 non-null    object
#  4   release_year       106 non-null    int64
#  5   release_date       106 non-null    object
#  6   runtime            106 non-null    int64
#  7   mpa_rating         106 non-null    object
#  8   mpa_rating_origin  106 non-null    object
#  9   imdb_score         106 non-null    float64
#  10  votes              106 non-null    int64
#  11  reviews_users      106 non-null    int64
#  12  reviews_critics    106 non-null    int64
#  13  budget             106 non-null    int64
#  14  income_usa         106 non-null    int64
#  15  income_ww          106 non-null    int64
#  16  theater_opening    106 non-null    int64
#  17  theater_total      106 non-null    int64
#  18  country_1          106 non-null    object
#  19  country_2          39 non-null     object
#  20  country_3          14 non-null     object
#  21  studio             106 non-null    object
#  22  director           106 non-null    object
#  23  Genre_1            106 non-null    object
#  24  Genre_2            103 non-null    object
#  25  Genre_3            96 non-null     object
#  26  actor_1            106 non-null    object
#  27  actor_2            106 non-null    object
#  28  actor_3            106 non-null    object
#  29  contract_price     106 non-null    int64
#  30  studio_score       106 non-null    int64
#  31  price_class        106 non-null    int64
# dtypes: float64(1), int64(14), object(17)
# memory usage: 26.6+ KB

# %% [markdown]
# ### 결측치 제거
# - country_2, country_3,Genre_2, Genre_3에서 결측치 확인
# - country관련 칼럼은 삭제 가능 (결측치가 너무 많다.)
# - Genre관련 데이터는 결측치가 별로 없기에 "ETC"라는 데이터로 대체

# %%
df_raw.isnull().sum()
# Out:
# item_id               0
# contract_year         0
# movie_id              0
# title                 0
# release_year          0
# release_date          0
# runtime               0
# mpa_rating            0
# mpa_rating_origin     0
# imdb_score            0
# votes                 0
# reviews_users         0
# reviews_critics       0
# budget                0
# income_usa            0
# income_ww             0
# theater_opening       0
# theater_total         0
# country_1             0
# country_2            67
# country_3            92
# studio                0
# director              0
# Genre_1               0
# Genre_2               3
# Genre_3              10
# actor_1               0
# actor_2               0
# actor_3               0
# contract_price        0
# studio_score          0
# price_class           0
# dtype: int64

# %%
df_raw = df_raw.drop(["country_2", "country_3"], axis = 1)

# %%
df_raw["Genre_1"].unique()
# Out:
# array(['Action', 'Adventure', 'Animation', 'Comedy', 'Biography', 'Drama',
#        'Horror'], dtype=object)

# %%
df_raw["Genre_2"].unique()
# Out:
# array(['Adventure', 'Family', 'Drama', 'Crime', nan, 'Comedy', 'Sci-Fi',
#        'Fantasy', 'Biography', 'Romance', 'Music', 'Thriller', 'Mystery',
#        'Horror', 'Action'], dtype=object)

# %%
df_raw["Genre_3"].unique()
# Out:
# array(['Fantasy', 'Sci-Fi', 'Comedy', 'Family', nan, 'Drama', 'Sport',
#        'Thriller', 'Mystery', 'Crime', 'Romance', 'History', 'Biography',
#        'Adventure', 'Music'], dtype=object)

# %%
df_raw = df_raw.fillna("ETC")

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   item_id            106 non-null    object
#  1   contract_year      106 non-null    int64
#  2   movie_id           106 non-null    object
#  3   title              106 non-null    object
#  4   release_year       106 non-null    int64
#  5   release_date       106 non-null    object
#  6   runtime            106 non-null    int64
#  7   mpa_rating         106 non-null    object
#  8   mpa_rating_origin  106 non-null    object
#  9   imdb_score         106 non-null    float64
#  10  votes              106 non-null    int64
#  11  reviews_users      106 non-null    int64
#  12  reviews_critics    106 non-null    int64
#  13  budget             106 non-null    int64
#  14  income_usa         106 non-null    int64
#  15  income_ww          106 non-null    int64
#  16  theater_opening    106 non-null    int64
#  17  theater_total      106 non-null    int64
#  18  country_1          106 non-null    object
#  19  studio             106 non-null    object
#  20  director           106 non-null    object
#  21  Genre_1            106 non-null    object
#  22  Genre_2            106 non-null    object
#  23  Genre_3            106 non-null    object
#  24  actor_1            106 non-null    object
#  25  actor_2            106 non-null    object
#  26  actor_3            106 non-null    object
#  27  contract_price     106 non-null    int64
#  28  studio_score       106 non-null    int64
#  29  price_class        106 non-null    int64
# dtypes: float64(1), int64(14), object(15)
# memory usage: 25.0+ KB

# %%
df_raw.to_csv('movie_inventory_change.csv', index=False, encoding='cp949')

# %% [markdown]
# ### 이상치 제거
# - 이산형 13개
# - 연속형 15개

# %% [markdown]
# ### 연속형 데이터 이상치 확인 결과
# - income_ww, votes, theater_opening, reviews_user에서 이상치를 확인했다.
# - 이상치 데이터를 세부적으로 살펴본 결과 income_ww에서 '아바타'가 매우 높은 수익률을 기록하고 있었다.
# - 배트맨 '다크나이트'가 리뷰 수 및 리뷰에 참여한 고객의 수에서 높은 수치를 기록했다.
# - 따라서 해당 데이터에서 이상치처럼 보였던 데이터에는 이상이 없는 것으로 확인되었다.'
#
# - 단 theter_opening에서는 오류가 발생한 것을 확인할 수 있었다.
#     - theater_total과 데이터를 확인했을 때 편차가 큰 것으로 나타났다.
#     - 따라서 해당 편차를 고려해서 이상치에 새로운 값을 넣어주었다.

# %%
df_raw_1 = df_raw
df_raw_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   item_id            106 non-null    object
#  1   contract_year      106 non-null    int64
#  2   movie_id           106 non-null    object
#  3   title              106 non-null    object
#  4   release_year       106 non-null    int64
#  5   release_date       106 non-null    object
#  6   runtime            106 non-null    int64
#  7   mpa_rating         106 non-null    object
#  8   mpa_rating_origin  106 non-null    object
#  9   imdb_score         106 non-null    float64
#  10  votes              106 non-null    int64
#  11  reviews_users      106 non-null    int64
#  12  reviews_critics    106 non-null    int64
#  13  budget             106 non-null    int64
#  14  income_usa         106 non-null    int64
#  15  income_ww          106 non-null    int64
#  16  theater_opening    106 non-null    int64
#  17  theater_total      106 non-null    int64
#  18  country_1          106 non-null    object
#  19  studio             106 non-null    object
#  20  director           106 non-null    object
#  21  Genre_1            106 non-null    object
#  22  Genre_2            106 non-null    object
#  23  Genre_3            106 non-null    object
#  24  actor_1            106 non-null    object
#  25  actor_2            106 non-null    object
#  26  actor_3            106 non-null    object
#  27  contract_price     106 non-null    int64
#  28  studio_score       106 non-null    int64
#  29  price_class        106 non-null    int64
# dtypes: float64(1), int64(14), object(15)
# memory usage: 25.0+ KB

# %%
df_raw[["theater_opening"]].boxplot()
# Out:
# <AxesSubplot:>

# %%
plt.subplot(221)
df_raw_1[["income_ww"]].boxplot(figs`ize = (40, 20))

plt.subplot(222)
df_raw_1[["votes"]].boxplot(figsize = (40, 20))

plt.subplot(223)
df_raw_1[["theater_opening"]].boxplot(figsize = (40, 20))

plt.subplot(224)
df_raw_1[["reviews_users"]].boxplot(figsize = (40, 20))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### reviews_users
# - 영화 리뷰 수(고객)

# %%
df_raw_1.sort_values(by="reviews_users", ascending=False).head()
# Out:
#     item_id  contract_year   movie_id                               title  \
# 12   I-1013           2015  tt0468569                     The Dark Knight
# 96   I-1097           2019  tt4154756              Avengers: Infinity War
# 105  I-1106           2019  tt1477834                             Aquaman
# 69   I-1070           2017  tt2975590  Batman v Superman: Dawn of Justice
# 25   I-1026           2015  tt1375666                           Inception
#
#      release_year release_date  runtime mpa_rating mpa_rating_origin  \
# 12           2008   07-18-2008      152      PG-13             PG-13
# 96           2018   04-27-2018      149      PG-13             PG-13
# 105          2018   12-21-2018      143      PG-13             PG-13
# 69           2016   03-25-2016      151      PG-13             PG-13
# 25           2010   07-16-2010      148      PG-13             PG-13
#
#      imdb_score  ...           director  Genre_1    Genre_2  Genre_3  \
# 12          9.0  ...  Christopher Nolan   Action      Crime    Drama
# 96          8.5  ...      Anthony Russo   Action  Adventure   Sci-Fi
# 105         7.0  ...          James Wan   Action  Adventure  Fantasy
# 69          6.5  ...        Zack Snyder   Action  Adventure   Sci-Fi
# 25          8.8  ...  Christopher Nolan   Action  Adventure   Sci-Fi
#
#                actor_1               actor_2        actor_3  contract_price  \
# 12      Christian Bale          Heath Ledger  Aaron Eckhart            2700
# 96   Robert Downey Jr.       Chris Hemsworth   Mark Ruffalo            2700
# 105        Jason Momoa           Amber Heard   Willem Dafoe            2295
# 69         Ben Affleck          Henry Cavill      Amy Adams            2295
# 25   Leonardo DiCaprio  Joseph Gordon-Levitt     Ellen Page            2700
#
#     studio_score price_class
# 12            10          10
# 96            10          10
# 105           10           1
# 69            10           1
# 25            10          10
#
# [5 rows x 30 columns]

# %% [markdown]
# ### votes
# - 리뷰를 작성한 유저 수

# %%
df_raw_1.sort_values(by="votes", ascending=False).head()
# Out:
#    item_id  contract_year   movie_id                    title  release_year  \
# 12  I-1013           2015  tt0468569          The Dark Knight          2008
# 25  I-1026           2015  tt1375666                Inception          2010
# 30  I-1031           2015  tt1345836    The Dark Knight Rises          2012
# 20  I-1021           2015  tt0499549                   Avatar          2009
# 41  I-1042           2015  tt2015381  Guardians of the Galaxy          2014
#
#    release_date  runtime mpa_rating mpa_rating_origin  imdb_score  ...  \
# 12   07-18-2008      152      PG-13             PG-13         9.0  ...
# 25   07-16-2010      148      PG-13             PG-13         8.8  ...
# 30   07-20-2012      164      PG-13             PG-13         8.4  ...
# 20   12-18-2009      162      PG-13             PG-13         7.8  ...
# 41   08-01-2014      121      PG-13             PG-13         8.1  ...
#
#              director  Genre_1    Genre_2  Genre_3            actor_1  \
# 12  Christopher Nolan   Action      Crime    Drama     Christian Bale
# 25  Christopher Nolan   Action  Adventure   Sci-Fi  Leonardo DiCaprio
# 30  Christopher Nolan   Action  Adventure      ETC     Christian Bale
# 20      James Cameron   Action  Adventure  Fantasy    Sam Worthington
# 41         James Gunn   Action  Adventure   Comedy        Chris Pratt
#
#                  actor_2           actor_3  contract_price studio_score  \
# 12          Heath Ledger     Aaron Eckhart            2700           10
# 25  Joseph Gordon-Levitt        Ellen Page            2700           10
# 30           Gary Oldman         Tom Hardy            2700           10
# 20           Zoe Saldana  Sigourney Weaver            2700           10
# 41           Zoe Saldana     Dave Bautista            2700           10
#
#    price_class
# 12          10
# 25          10
# 30          10
# 20          10
# 41          10
#
# [5 rows x 30 columns]

# %% [markdown]
# ### income_ww
# - 매출(전세계)

# %%
df_raw_1.sort_values(by="income_ww", ascending=False).head()
# Out:
#    item_id  contract_year   movie_id                    title  release_year  \
# 20  I-1021           2015  tt0499549                   Avatar          2009
# 96  I-1097           2019  tt4154756   Avengers: Infinity War          2018
# 52  I-1053           2016  tt0369610           Jurassic World          2015
# 47  I-1048           2016  tt2395427  Avengers: Age of Ultron          2015
# 94  I-1095           2019  tt1825683            Black Panther          2018
#
#    release_date  runtime mpa_rating mpa_rating_origin  imdb_score  ...  \
# 20   12-18-2009      162      PG-13             PG-13         7.8  ...
# 96   04-27-2018      149      PG-13             PG-13         8.5  ...
# 52   06-12-2015      124      PG-13             PG-13         7.0  ...
# 47   05-01-2015      141      PG-13             PG-13         7.3  ...
# 94   02-16-2018      134      PG-13             PG-13         7.3  ...
#
#            director  Genre_1    Genre_2  Genre_3            actor_1  \
# 20    James Cameron   Action  Adventure  Fantasy    Sam Worthington
# 96    Anthony Russo   Action  Adventure   Sci-Fi  Robert Downey Jr.
# 52  Colin Trevorrow   Action  Adventure   Sci-Fi        Chris Pratt
# 47      Joss Whedon   Action  Adventure   Sci-Fi  Robert Downey Jr.
# 94     Ryan Coogler   Action  Adventure   Sci-Fi   Chadwick Boseman
#
#                 actor_2           actor_3  contract_price studio_score  \
# 20          Zoe Saldana  Sigourney Weaver            2700           10
# 96      Chris Hemsworth      Mark Ruffalo            2700           10
# 52  Bryce Dallas Howard       Irrfan Khan            2295           10
# 47      Chris Hemsworth      Mark Ruffalo            2295           10
# 94    Michael B. Jordan    Lupita Nyong'o            2295           10
#
#    price_class
# 20          10
# 96          10
# 52           1
# 47           1
# 94           1
#
# [5 rows x 30 columns]

# %% [markdown]
# ### theater_opening
#
# - 개봉 극장 수 이상해보임

# %%
cond = (df_raw_1["theater_opening"] ==1) | (df_raw_1["theater_opening"] ==4) | (df_raw_1["theater_opening"] ==25)

df_raw_1[cond]
# Out:
#    item_id  contract_year   movie_id            title  release_year  \
# 38  I-1039           2015  tt2294629           Frozen          2013
# 44  I-1045           2015  tt2179136  American Sniper          2014
# 66  I-1067           2016  tt1663202     The Revenant          2015
# 81  I-1082           2017  tt4846340   Hidden Figures          2016
#
#    release_date  runtime mpa_rating mpa_rating_origin  imdb_score  ...  \
# 38   11-27-2013      102         PG                PG         7.5  ...
# 44   01-16-2015      133          R                 R         7.3  ...
# 66   01-08-2016      156          R                 R         8.0  ...
# 81   01-06-2017      127         PG                PG         7.8  ...
#
#           director    Genre_1    Genre_2    Genre_3            actor_1  \
# 38      Chris Buck  Animation  Adventure     Comedy       Kristen Bell
# 44  Clint Eastwood     Action  Biography      Drama     Bradley Cooper
# 66  Alejandro G. I     Action  Adventure  Biography  Leonardo DiCaprio
# 81  Theodore Melfi  Biography      Drama    History   Taraji P. Henson
#
#             actor_2           actor_3  contract_price studio_score price_class
# 38     Idina Menzel    Jonathan Groff            2700           10          10
# 44     Kyle Gallner        Cole Konis            2295           10           1
# 66        Tom Hardy  Domhnall Gleeson            2600            6          10
# 81  Octavia Spencer     Janelle Mon　e            2600            6          10
#
# [4 rows x 30 columns]

# %%
df_raw_1["total-opening"] = df_raw_1["theater_total"] - df_raw_1["theater_opening"]

# %%
plt.boxplot(df_raw_1["total-opening"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1cdc504850>,
#   <matplotlib.lines.Line2D at 0x7f1cdc504490>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1cdacb3100>,
#   <matplotlib.lines.Line2D at 0x7f1cdb60dbe0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1cdb09ddc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1cdb60dac0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1cdb60d1c0>],
#  'means': []}

# %%
df_raw_1.sort_values(by="total-opening", ascending=False).head()
# Out:
#    item_id  contract_year   movie_id                   title  release_year  \
# 44  I-1045           2015  tt2179136         American Sniper          2014
# 38  I-1039           2015  tt2294629                  Frozen          2013
# 66  I-1067           2016  tt1663202            The Revenant          2015
# 81  I-1082           2017  tt4846340          Hidden Figures          2016
# 58  I-1059           2016  tt1398426  Straight Outta Compton          2015
#
#    release_date  runtime mpa_rating mpa_rating_origin  imdb_score  ...  \
# 44   01-16-2015      133          R                 R         7.3  ...
# 38   11-27-2013      102         PG                PG         7.5  ...
# 66   01-08-2016      156          R                 R         8.0  ...
# 81   01-06-2017      127         PG                PG         7.8  ...
# 58   08-14-2015      147          R                 R         7.9  ...
#
#       Genre_1    Genre_2    Genre_3             actor_1          actor_2  \
# 44     Action  Biography      Drama      Bradley Cooper     Kyle Gallner
# 38  Animation  Adventure     Comedy        Kristen Bell     Idina Menzel
# 66     Action  Adventure  Biography   Leonardo DiCaprio        Tom Hardy
# 81  Biography      Drama    History    Taraji P. Henson  Octavia Spencer
# 58  Biography      Drama    History  O'Shea Jackson Jr.    Corey Hawkins
#
#              actor_3  contract_price  studio_score price_class total-opening
# 44        Cole Konis            2295            10           1          3881
# 38    Jonathan Groff            2700            10          10          3741
# 66  Domhnall Gleeson            2600             6          10          3707
# 81     Janelle Mon　e            2600             6          10          3391
# 58    Jason Mitchell            2600             6          10           385
#
# [5 rows x 31 columns]

# %% [markdown]
# - American Sniper, Frozen, The Revenant, Hidden Figures 데이터에서 theater_opening과 theater_total에서 차이점이 존재하는 것 같다.

# %%
bin_ls = ["country_1", "studio", "director", "Genre_1", "Genre_2", "Genre_3",
          "actor_1", "actor_2", "actor_3"]

fig, ax = plt.subplots(3, 3, figsize=(20, 20))
i, j = 0, 0

for col in bin_ls:
    ax[i, j].hist(df_raw_1[col])
    i += 1
    if i == 3:
        i = 0
        j += 1

# %% [markdown]
# ### 이산형 데이터 정리
# - 영화배우, 영화 감독 데이터의 경우 전체적으로 분포가 다양하게 나타나고 있다.
# - 장르의 경우 Action, Adventure의 경우가 주를 이루는 것을 확인할 수 있었다.
# - 단 MPA등급의 경우 데이터가 아예 동일한 형태를 띠고 있기 때문에 추후 작업 시 해당 칼럼 중 하나를 제거하고 진행하도록 하겠다.

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))

ax[0].hist(df_raw_1['mpa_rating'])
ax[1].hist(df_raw_1['mpa_rating_origin'])
# Out:
# (array([67.,  0.,  0., 23.,  0.,  0., 13.,  0.,  0.,  3.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_raw_1['mpa_rating'], label = "MPA등급", alpha = 0.5)
plt.hist(df_raw_1['mpa_rating_origin'], label = "MPA등급(기존)", alpha = 0.5)
plt.title("MPA등급")
plt.legend()

# %%
df_raw_1[df_raw_1["mpa_rating"]=="R"]
# Out:
#    item_id  contract_year   movie_id                   title  release_year  \
# 15  I-1016           2015  tt1119646            The Hangover          2009
# 26  I-1027           2015  tt1411697    The Hangover Part II          2011
# 44  I-1045           2015  tt2179136         American Sniper          2014
# 46  I-1047           2016  tt2322441    Fifty Shades of Grey          2015
# 48  I-1049           2016  tt1392190      Mad Max: Fury Road          2015
# 51  I-1052           2016  tt3079380                     Spy          2015
# 56  I-1057           2016  tt3152624              Trainwreck          2015
# 58  I-1059           2016  tt1398426  Straight Outta Compton          2015
# 66  I-1067           2016  tt1663202            The Revenant          2015
# 67  I-1068           2017  tt1431045                Deadpool          2016
# 82  I-1083           2018  tt5052448                 Get Out          2017
# 89  I-1090           2018  tt1396484                      It          2017
# 97  I-1098           2019  tt5463162              Deadpool 2          2018
#
#    release_date  runtime mpa_rating mpa_rating_origin  imdb_score  ...  \
# 15   06-05-2009      100          R                 R         7.7  ...
# 26   05-26-2011      102          R                 R         6.4  ...
# 44   01-16-2015      133          R                 R         7.3  ...
# 46   02-13-2015      125          R                 R         4.1  ...
# 48   05-15-2015      120          R                 R         8.1  ...
# 51   06-05-2015      119          R                 R         7.0  ...
# 56   07-17-2015      125          R                 R         6.2  ...
# 58   08-14-2015      147          R                 R         7.9  ...
# 66   01-08-2016      156          R                 R         8.0  ...
# 67   02-12-2016      108          R                 R         8.0  ...
# 82   02-24-2017      104          R                 R         7.7  ...
# 89   09-08-2017      135          R                 R         7.4  ...
# 97   05-18-2018      119          R                 R         7.7  ...
#
#       Genre_1    Genre_2    Genre_3             actor_1            actor_2  \
# 15     Comedy        ETC        ETC      Bradley Cooper           Ed Helms
# 26     Comedy        ETC        ETC      Bradley Cooper           Ed Helms
# 44     Action  Biography      Drama      Bradley Cooper       Kyle Gallner
# 46      Drama    Romance   Thriller      Dakota Johnson       Jamie Dornan
# 48     Action  Adventure     Sci-Fi           Tom Hardy    Charlize Theron
# 51     Action     Comedy      Crime            Jude Law          Raad Rawi
# 56     Comedy      Drama    Romance         Colin Quinn        Devin Fabry
# 58  Biography      Drama    History  O'Shea Jackson Jr.      Corey Hawkins
# 66     Action  Adventure  Biography   Leonardo DiCaprio          Tom Hardy
# 67     Action  Adventure     Comedy       Ryan Reynolds         Karan Soni
# 82     Horror    Mystery   Thriller      Daniel Kaluuya   Allison Williams
# 89     Horror        ETC        ETC      Jaeden Martell  Jeremy Ray Taylor
# 97     Action  Adventure     Comedy       Ryan Reynolds        Josh Brolin
#
#               actor_3  contract_price  studio_score price_class total-opening
# 15  Zach Galifianakis            2700            10          10           276
# 26  Zach Galifianakis            2295            10           1            60
# 44         Cole Konis            2295            10           1          3881
# 46      Jennifer Ehle            2295            10           1             9
# 48     Nicholas Hoult            2700            10          10            20
# 51   Melissa McCarthy            2195             6           1             4
# 56        Carla Oudin            2295            10           1            13
# 58     Jason Mitchell            2600             6          10           385
# 66   Domhnall Gleeson            2600             6          10          3707
# 67          Ed Skrein            2600             6          10           298
# 82   Catherine Keener            2550             4          10           362
# 89      Sophia Lillis            2195             6           1            45
# 97    Morena Baccarin            2600             6          10             0
#
# [13 rows x 31 columns]

# %%
df_raw_2 = df_raw_1.drop("mpa_rating_origin", axis=1)

# %%
df_raw_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total
# 36        91      PG-13         7.7   725663  ...      Drama     Sci-Fi
# 37       146      PG-13         7.5   584383  ...     Action  Adventure
# 38       102         PG         7.5   528717  ...  Animation  Adventure
# 39       161      PG-13         7.8   574091  ...  Adventure    Fantasy
# 40       136      PG-13         7.8   687645  ...     Action  Adventure
# 41       121      PG-13         8.1   980782  ...     Action  Adventure
# 48       120          R         8.1   805017  ...     Action  Adventure
# 53        95         PG         8.2   556161  ...  Animation  Adventure
# 58       147          R         7.9   168582  ...  Biography      Drama
# 60       144      PG-13         8.0   701756  ...  Adventure      Drama
# 66       156          R         8.0   643256  ...     Action  Adventure
# 67       108          R         8.0   845841  ...     Action  Adventure
# 68       108         PG         8.0   396148  ...  Animation  Adventure
# 70       147      PG-13         7.8   608928  ...     Action  Adventure
# 77       115      PG-13         7.5   541463  ...     Action  Adventure
# 79       107         PG         7.6   236171  ...  Animation  Adventure
# 81       127         PG         7.8   177833  ...  Biography      Drama
# 82       104          R         7.7   429173  ...     Horror    Mystery
# 84       136      PG-13         7.6   510984  ...     Action  Adventure
# 87       133      PG-13         7.5   460468  ...     Action  Adventure
# 88       106      PG-13         7.9   487517  ...     Action      Drama
# 90       130      PG-13         7.9   518571  ...     Action  Adventure
# 92       105         PG         8.4   305662  ...  Animation  Adventure
# 95        90      PG-13         7.5   333041  ...      Drama     Horror
# 96       149      PG-13         8.5   725138  ...     Action  Adventure
# 97       119          R         7.7   424573  ...     Action  Adventure
# 99       118         PG         7.7   219133  ...  Animation     Action
# 102      147      PG-13         7.8   251993  ...     Action  Adventure
# 103      134      PG-13         8.0   392599  ...  Biography      Drama
#
#        Genre_3               actor_1               actor_2  \
# 0      Fantasy         Ewan McGregor       Natalie Portman
# 1      Fantasy            Eric Sykes         Timothy Spall
# 8       Family      Daniel Radcliffe         Harry Melling
# 10      Sci-Fi     Robert Downey Jr.       Terrence Howard
# 12       Drama        Christian Bale          Heath Ledger
# 13      Sci-Fi            Chris Pine        Zachary Quinto
# 14      Comedy          Edward Asner   Christopher Plummer
# 15         ETC        Bradley Cooper              Ed Helms
# 17      Family      Daniel Radcliffe        Michael Gambon
# 18       Sport        Sandra Bullock            Tim McGraw
# 20     Fantasy       Sam Worthington           Zoe Saldana
# 22      Comedy             Tom Hanks             Tim Allen
# 24      Family          Steve Carell           Jason Segel
# 25      Sci-Fi     Leonardo DiCaprio  Joseph Gordon-Levitt
# 30         ETC        Christian Bale           Gary Oldman
# 31    Thriller          Daniel Craig            Judi Dench
# 32     Fantasy          Ian McKellen        Martin Freeman
# 36    Thriller        Sandra Bullock        George Clooney
# 37     Mystery     Jennifer Lawrence        Liam Hemsworth
# 38      Comedy          Kristen Bell          Idina Menzel
# 39         ETC          Ian McKellen        Martin Freeman
# 40      Sci-Fi           Chris Evans     Samuel L. Jackson
# 41      Comedy           Chris Pratt           Zoe Saldana
# 48      Sci-Fi             Tom Hardy       Charlize Theron
# 53      Comedy           Amy Poehler         Phyllis Smith
# 58     History    O'Shea Jackson Jr.         Corey Hawkins
# 60      Sci-Fi            Matt Damon      Jessica Chastain
