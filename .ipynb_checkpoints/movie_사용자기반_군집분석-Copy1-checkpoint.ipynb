# %%
import pandas as pd

# %%
down = pd.read_csv('movie_down.csv', engine = 'python')
customer = pd.read_csv('movie_customer.csv', engine = 'python', encoding='cp949')
inventory = pd.read_csv('movie_inventory.csv', engine = 'python')

display(down.head())
display(down.info())
display(customer.head())
display(inventory.head())
# Out:
#   customer_id item_id   down_date  down_year down_month down_weekday
# 0       C5001  I-1038  2015-01-08       2015    2015M01          Thu
# 1       C5001  I-1003  2015-01-17       2015    2015M01          Sat
# 2       C5001  I-1017  2015-01-17       2015    2015M01          Sat
# 3       C5001  I-1028  2015-01-19       2015    2015M01          Mon
# 4       C5001  I-1036  2015-01-20       2015    2015M01          Tue
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116464 entries, 0 to 116463
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   customer_id   116464 non-null  object
#  1   item_id       116464 non-null  object
#  2   down_date     116464 non-null  object
#  3   down_year     116464 non-null  int64
#  4   down_month    116464 non-null  object
#  5   down_weekday  116464 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 5.3+ MB
# None
# ...

# %%
customer[(customer['age_group'] == '20대') & (customer['gender'] == 'F')]
# Out:
#      customer_id gender  age age_group married kids_under12  area  \
# 3          C5004      F   24       20대       M            N  서대문구
# 17         C5018      F   28       20대       S            N   동작구
# 30         C5031      F   21       20대       M            Y   마포구
# 40         C5041      F   21       20대       M            N   강남구
# 41         C5042      F   22       20대       M            N   용산구
# ...          ...    ...  ...       ...     ...          ...   ...
# 3229       C8230      F   20       20대       S            N   관악구
# 3262       C8263      F   23       20대       M            Y   양천구
# 3263       C8264      F   24       20대       M            Y   용산구
# 3270       C8271      F   21       20대       M            Y   마포구
# 3273       C8274      F   24       20대       M            N   송파구
#
#       subs_start_year
# 3                2015
# 17               2015
# 30               2015
# 40               2015
# 41               2015
# ...               ...
# ...

# %%
new_down = pd.merge(down, customer, on = 'customer_id')
new_down
# Out:
#        customer_id item_id   down_date  down_year down_month down_weekday  \
# 0            C5001  I-1038  2015-01-08       2015    2015M01          Thu
# 1            C5001  I-1003  2015-01-17       2015    2015M01          Sat
# 2            C5001  I-1017  2015-01-17       2015    2015M01          Sat
# 3            C5001  I-1028  2015-01-19       2015    2015M01          Mon
# 4            C5001  I-1036  2015-01-20       2015    2015M01          Tue
# ...            ...     ...         ...        ...        ...          ...
# 116459       C8277  I-1087  2018-09-21       2018    2018M09          Fri
# 116460       C8277  I-1090  2018-09-29       2018    2018M09          Sat
# 116461       C8277  I-1088  2018-10-24       2018    2018M10          Wed
# 116462       C8277  I-1091  2018-10-25       2018    2018M10          Thu
# 116463       C8277  I-1016  2018-11-15       2018    2018M11          Thu
#
#        gender  age age_group married kids_under12 area  subs_start_year
# ...

# %%
down_20 = new_down[(new_down['age_group'] == '20대') & (new_down['gender'] == 'F') & (new_down['down_year'] == 2015)]
down_20.head()
# Out:
#     customer_id item_id   down_date  down_year down_month down_weekday gender  \
# 133       C5004  I-1021  2015-02-06       2015    2015M02          Fri      F
# 134       C5004  I-1034  2015-02-26       2015    2015M02          Thu      F
# 135       C5004  I-1011  2015-03-20       2015    2015M03          Fri      F
# 136       C5004  I-1028  2015-05-02       2015    2015M05          Sat      F
# 137       C5004  I-1003  2015-06-17       2015    2015M06          Wed      F
#
#      age age_group married kids_under12  area  subs_start_year
# 133   24       20대       M            N  서대문구             2015
# 134   24       20대       M            N  서대문구             2015
# 135   24       20대       M            N  서대문구             2015
# 136   24       20대       M            N  서대문구             2015
# 137   24       20대       M            N  서대문구             2015

# %%
movie_list_5004 = list(pd.unique(down_20[down_20['customer_id'] == 'C5004']['item_id']))
movie_list_5004
# Out:
# ['I-1021',
#  'I-1034',
#  'I-1011',
#  'I-1028',
#  'I-1003',
#  'I-1036',
#  'I-1004',
#  'I-1006',
#  'I-1013',
#  'I-1031']

# %%
movie_list = list(pd.unique(down_20['item_id']))
for i in range(len(movie_list_5004)):
    movie_list.remove(movie_list_5004[i])
movie_list
# Out:
# ['I-1041',
#  'I-1035',
#  'I-1012',
#  'I-1019',
#  'I-1007',
#  'I-1016',
#  'I-1005',
#  'I-1014',
#  'I-1002',
#  'I-1015',
#  'I-1044',
#  'I-1038',
#  'I-1042',
#  'I-1010',
#  'I-1001',
#  'I-1039',
#  'I-1032',
#  'I-1040',
#  'I-1043',
#  'I-1029',
#  'I-1008',
#  'I-1033',
#  'I-1020',
#  'I-1022',
#  'I-1025',
#  'I-1018',
#  'I-1037',
#  'I-1030',
#  'I-1045',
#  'I-1009',
#  'I-1017',
#  'I-1026',
#  'I-1027',
#  'I-1023']

# %%
down_20_inv = inventory[(inventory['item_id'] == 'I-1041')|(inventory['item_id'] == 'I-1035') | (inventory['item_id'] == 'I-1012') |
         (inventory['item_id'] == 'I-1019') |(inventory['item_id'] == 'I-1007') | (inventory['item_id'] == 'I-1016') |
         (inventory['item_id'] == 'I-1005') |(inventory['item_id'] == 'I-1014') | (inventory['item_id'] == 'I-1002') |
         (inventory['item_id'] == 'I-1015') |(inventory['item_id'] == 'I-1044') | (inventory['item_id'] == 'I-1038') |
         (inventory['item_id'] == 'I-1042') |(inventory['item_id'] == 'I-1010') | (inventory['item_id'] == 'I-1001') |
         (inventory['item_id'] == 'I-1039') |(inventory['item_id'] == 'I-1032') | (inventory['item_id'] == 'I-1040') |
         (inventory['item_id'] == 'I-1043') |(inventory['item_id'] == 'I-1029') | (inventory['item_id'] == 'I-1008') |
         (inventory['item_id'] == 'I-1033') |(inventory['item_id'] == 'I-1020') | (inventory['item_id'] == 'I-1022') |
         (inventory['item_id'] == 'I-1025') |(inventory['item_id'] == 'I-1018') | (inventory['item_id'] == 'I-1037') |
         (inventory['item_id'] == 'I-1030') |(inventory['item_id'] == 'I-1045') | (inventory['item_id'] == 'I-1009') |
         (inventory['item_id'] == 'I-1017') |(inventory['item_id'] == 'I-1026') | (inventory['item_id'] == 'I-1027') |
         (inventory['item_id'] == 'I-1023')]

down_20_inv
# Out:
#    item_id  contract_year   movie_id  \
# 0   I-1001           2015  tt0121766
# 1   I-1002           2015  tt0330373
# 4   I-1005           2015  tt0413300
# 6   I-1007           2015  tt0449088
# 7   I-1008           2015  tt0418279
# 8   I-1009           2015  tt0373889
# 9   I-1010           2015  tt0480249
# 11  I-1012           2015  tt0367882
# 13  I-1014           2015  tt0796366
# 14  I-1015           2015  tt1049413
# 15  I-1016           2015  tt1119646
# 16  I-1017           2015  tt1055369
# 17  I-1018           2015  tt0417741
# 18  I-1019           2015  tt0878804
# 19  I-1020           2015  tt1259571
# 21  I-1022           2015  tt1228705
# 22  I-1023           2015  tt0435761
# 24  I-1025           2015  tt1323594
# 25  I-1026           2015  tt1375666
# 26  I-1027           2015  tt1411697
# 28  I-1029           2015  tt1392170
# 29  I-1030           2015  tt0948470
# 31  I-1032           2015  tt1074638
# 32  I-1033           2015  tt0903624
# ...

# %%
studio_name = down_20_inv['studio'].unique()
studio_num = [i for i in range(len(studio_name))]

studio = pd.DataFrame({'studio' : studio_name,
                       'studio_num' : studio_num})
studio
# Out:
#                    studio  studio_num
# 0        20th Century Fox           0
# 1                      WB           1
# 2  Sony Pictures/Columbia           2
# 3             BUENA VISTA           3
# 4                    P/DW           4
# 5               Paramount           5
# 6                    Sum.           6
# 7               Universal           7
# 8               LIONSGATE           8
# 9                 WB (NL)           9

# %%
director_name = down_20_inv['director'].unique()
director_num = [i for i in range(len(director_name))]

director = pd.DataFrame({'director' : director_name,
                        'director_num' : director_num})

director
# Out:
#              director  director_num
# 0        George Lucas             0
# 1         Mike Newell             1
# 2           Sam Raimi             2
# 3      Gore Verbinski             3
# 4         Michael Bay             4
# 5         David Yates             5
# 6    Francis Lawrence             6
# 7    Steven Spielberg             7
# 8         J.J. Abrams             8
# 9         Pete Docter             9
# 10      Todd Phillips            10
# 11   John Lee Hancock            11
# 12        Chris Weitz            12
# 13        Jon Favreau            13
# 14        Lee Unkrich            14
# 15      Pierre Coffin            15
# 16  Christopher Nolan            16
# 17          Gary Ross            17
# 18          Marc Webb            18
# 19         Sam Mendes            19
# 20      Peter Jackson            20
# 21        Dan Scanlon            21
# 22      Alfonso Cuarn            22
# 23         Chris Buck            23
# 24      Anthony Russo            24
# ...

# %%
genre_name = down_20_inv['Genre_1'].unique()
genre_num = [i for i in range(len(genre_name))]

genre = pd.DataFrame({'Genre_1' : genre_name,
                     'genre_num' : genre_num})

genre
# Out:
#      Genre_1  genre_num
# 0     Action          0
# 1  Adventure          1
# 2  Animation          2
# 3     Comedy          3
# 4  Biography          4
# 5      Drama          5

# %%
down_20_inv = pd.merge(down_20_inv, studio, on = 'studio')
down_20_inv = pd.merge(down_20_inv, director, on = 'director')
down_20_inv = pd.merge(down_20_inv, genre, on = 'Genre_1')
down_20_inv.head()
# Out:
#   item_id  contract_year   movie_id  \
# 0  I-1001           2015  tt0121766
# 1  I-1009           2015  tt0373889
# 2  I-1018           2015  tt0417741
# 3  I-1038           2015  tt1951264
# 4  I-1043           2015  tt1951265
#
#                                           title   price  release_year  \
# 0  Star Wars: Episode III - Revenge of the Sith  5500.0          2005
# 1     Harry Potter and the Order of the Phoenix  4500.0          2007
# 2        Harry Potter and the Half-Blood Prince  4500.0          2009
# 3               The Hunger Games: Catching Fire     NaN          2013
# 4         The Hunger Games: Mockingjay - Part 1  1200.0          2014
#
#   release_date  runtime mpa_rating mpa_rating_origin  ...  Genre_3  \
# 0   05-19-2005      140      PG-13             PG-13  ...  Fantasy
# 1   07-11-2007      138      PG-13             PG-13  ...   Family
# 2   07-15-2009      153         PG                PG  ...   Family
# ...

# %%
from sklearn_extra.cluster import KMedoids

# %%
n_iter = 15
cluster_range = [i+1 for i in range(n_iter)]
clus_error = []

for v in cluster_range:
    clus = KMedoids(n_clusters=v)
    clus.fit(down_20_inv[['studio_num', 'director_num', 'genre_num']])
    clus_error.append(clus.inertia_)

ds_error = pd.DataFrame({'NumberofCluster':cluster_range,
                       'Error':clus_error})
ds_error
# Out:
# /home/piai/anaconda3/lib/python3.8/site-packages/sklearn_extra/cluster/_k_medoids.py:231: UserWarning: Cluster 6 is empty! self.labels_[self.medoid_indices_[6]] may not be labeled with its corresponding cluster (6).
#   warnings.warn(
# /home/piai/anaconda3/lib/python3.8/site-packages/sklearn_extra/cluster/_k_medoids.py:231: UserWarning: Cluster 6 is empty! self.labels_[self.medoid_indices_[6]] may not be labeled with its corresponding cluster (6).
#   warnings.warn(
# /home/piai/anaconda3/lib/python3.8/site-packages/sklearn_extra/cluster/_k_medoids.py:231: UserWarning: Cluster 6 is empty! self.labels_[self.medoid_indices_[6]] may not be labeled with its corresponding cluster (6).
#   warnings.warn(
# /home/piai/anaconda3/lib/python3.8/site-packages/sklearn_extra/cluster/_k_medoids.py:231: UserWarning: Cluster 6 is empty! self.labels_[self.medoid_indices_[6]] may not be labeled with its corresponding cluster (6).
#   warnings.warn(
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10, 10))
plt.plot(ds_error['NumberofCluster'], ds_error['Error'])
plt.title('Sum of squared distance')
# Out:
# Text(0.5, 1.0, 'Sum of squared distance')

# %%
clus = KMedoids(6)
clus.fit(down_20_inv[['studio_num', 'director_num', 'genre_num']])

cluster_kmeans = [i+1 for i in clus.labels_]
down_20_inv["ClusterKmeans"] = cluster_kmeans
down_20_inv.head()
# Out:
#   item_id  contract_year   movie_id  \
# 0  I-1001           2015  tt0121766
# 1  I-1009           2015  tt0373889
# 2  I-1018           2015  tt0417741
# 3  I-1038           2015  tt1951264
# 4  I-1043           2015  tt1951265
#
#                                           title   price  release_year  \
# 0  Star Wars: Episode III - Revenge of the Sith  5500.0          2005
# 1     Harry Potter and the Order of the Phoenix  4500.0          2007
# 2        Harry Potter and the Half-Blood Prince  4500.0          2009
# 3               The Hunger Games: Catching Fire     NaN          2013
# 4         The Hunger Games: Mockingjay - Part 1  1200.0          2014
#
#   release_date  runtime mpa_rating mpa_rating_origin  ...            actor_1  \
# 0   05-19-2005      140      PG-13             PG-13  ...      Ewan McGregor
# 1   07-11-2007      138      PG-13             PG-13  ...   Daniel Radcliffe
# 2   07-15-2009      153         PG                PG  ...   Daniel Radcliffe
# ...

# %%
down_20_inv[['item_id', 'studio', 'director', 'Genre_1', 'studio_num', 'director_num', 'genre_num', 'ClusterKmeans']]
# Out:
#    item_id                  studio           director    Genre_1  studio_num  \
# 0   I-1001        20th Century Fox       George Lucas     Action           0
# 1   I-1009                      WB        David Yates     Action           1
# 2   I-1018                      WB        David Yates     Action           1
# 3   I-1038               LIONSGATE   Francis Lawrence     Action           8
# 4   I-1043               LIONSGATE   Francis Lawrence     Action           8
# 5   I-1026                      WB  Christopher Nolan     Action           1
# 6   I-1045                      WB     Clint Eastwood     Action           1
# 7   I-1005  Sony Pictures/Columbia          Sam Raimi     Action           2
# 8   I-1030  Sony Pictures/Columbia          Marc Webb     Action           2
# 9   I-1032  Sony Pictures/Columbia         Sam Mendes     Action           2
# 10  I-1007             BUENA VISTA     Gore Verbinski     Action           3
# ...

# %%
plt.scatter(down_20_inv['studio_num'], down_20_inv['genre_num'], c = down_20_inv['ClusterKmeans'])
plt.xlabel('studio_num')
plt.ylabel('genre_num')
# Out:
# No handles with labels found to put in legend.

# %%
down_20[down_20['customer_id'] == 'C5004']
# Out:
#     customer_id item_id   down_date  down_year down_month down_weekday gender  \
# 133       C5004  I-1021  2015-02-06       2015    2015M02          Fri      F
# 134       C5004  I-1034  2015-02-26       2015    2015M02          Thu      F
# 135       C5004  I-1011  2015-03-20       2015    2015M03          Fri      F
# 136       C5004  I-1028  2015-05-02       2015    2015M05          Sat      F
# 137       C5004  I-1003  2015-06-17       2015    2015M06          Wed      F
# 138       C5004  I-1036  2015-07-09       2015    2015M07          Thu      F
# 139       C5004  I-1036  2015-08-10       2015    2015M08          Mon      F
# 140       C5004  I-1004  2015-08-14       2015    2015M08          Fri      F
# 141       C5004  I-1006  2015-10-08       2015    2015M10          Thu      F
# 142       C5004  I-1013  2015-10-10       2015    2015M10          Sat      F
# 143       C5004  I-1006  2015-11-16       2015    2015M11          Mon      F
# ...

# %%
down_20_5004 = inventory[(inventory['item_id'] == 'I-1021')|(inventory['item_id'] == 'I-1034') | (inventory['item_id'] == 'I-1011') |
         (inventory['item_id'] == 'I-1028') |(inventory['item_id'] == 'I-1003') | (inventory['item_id'] == 'I-1036') |
         (inventory['item_id'] == 'I-1004') |(inventory['item_id'] == 'I-1013') | (inventory['item_id'] == 'I-1031') |
         (inventory['item_id'] == 'I-1006')]

down_20_5004
# Out:
#    item_id  contract_year   movie_id  \
# 2   I-1003           2015  tt0363771
# 3   I-1004           2015  tt0383574
# 5   I-1006           2015  tt0413267
# 10  I-1011           2015  tt0371746
# 12  I-1013           2015  tt0468569
# 20  I-1021           2015  tt0499549
# 27  I-1028           2015  tt1399103
# 30  I-1031           2015  tt1345836
# 33  I-1034           2015  tt0770828
# 35  I-1036           2015  tt1690953
#
#                                            title   price  release_year  \
# 2   The Chronicles of Narnia: The Lion, the Witc  5500.0          2005
# 3     Pirates of the Caribbean: Dead Man's Chest  5500.0          2006
# 5                                Shrek the Third     NaN          2007
# 10                                      Iron Man  5500.0          2008
# 12                               The Dark Knight  4500.0          2008
# 20                                        Avatar  4000.0          2009
# ...

# %%
import seaborn as sns

# %%
sns.countplot(down_20_5004['Genre_1'])
# Out:
# /home/piai/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Genre_1', ylabel='count'>

# %%
sns.countplot(down_20_5004['studio'])
# Out:
# /home/piai/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='studio', ylabel='count'>

# %%
sns.countplot(down_20_5004['director'])
# Out:
# /home/piai/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='director', ylabel='count'>

# %%
#I, 2, 9 , 10, 18
#20, 32, 15, 27, 22
down_20.groupby('item_id').count()

#2, 10, 18, 1, 9 번 순으로 추천
# Out:
#          customer_id  down_date  down_year  down_month  down_weekday  gender  \
# item_id
# I-1001            20         20         20          20            20      20
# I-1002            32         32         32          32            32      32
# I-1003            21         21         21          21            21      21
# I-1004            13         13         13          13            13      13
# I-1005            45         45         45          45            45      45
# I-1006            20         20         20          20            20      20
# I-1007            16         16         16          16            16      16
# I-1008            18         18         18          18            18      18
# I-1009            15         15         15          15            15      15
# I-1010            27         27         27          27            27      27
# I-1011            42         42         42          42            42      42
# ...
